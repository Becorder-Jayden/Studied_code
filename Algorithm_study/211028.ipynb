# %% [markdown]
# # 2021.10.28

# %%
# Silver V
# 10867 중복 빼고 정렬하기

N = int(input())
num = list(map(int, input().split()))
s_num = sorted(set(num))

for i in s_num:
    print(i, end = ' ')
# Out:
#  2
#  1 2 3 4 2 3 4 5
# 1 2 3 4 5

# %%
# print(옵션으로 *을 기입해도) 동일하게 결과를 출력할 수 있다
print(*s_num)
# Out:
# 1 2 3 4 5

# %% [markdown]
# ---

# %%
# 알고리즘이란 이것이다?
# 속도문제가 발생했을 때 수학적인 방법으로 푸는 방법? 
# Silver V
# 1934 최소공배수

T = int(input())

for i in range(T):

    A, B = map(int, input().split())
    lis_A = []
    lis_B = []
    lis_T = []
    
    if A == 1:
        lis_T.append(B)
    elif: B == 1:
        lis_T.append(A)
    else:
        for j in range(1, A+1):
            if A/j - A//j == 0:
                lis_T.append(j)

        for j in range(1, B+1):
            if B/j - B//j == 0:
                lis_T.append(j)

        lis_T = set(lis_T)
    print(lis_T)
    
#     m = 1
#     for i in lis_T:
#         m = m*i
#     print(m)
# Out:
#   File "<ipython-input-71-4adf2fd96c5d>", line 17
#     elif: B == 1:
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 대근 선생님
# 아마 런타임에러가 뜰 예정, 속도문제를 의도한 문제
# 1. 최소공배수는 두수의 곱을 최대공약수로 나누면 된다.
# 2. 어떻게 하면 최대공약수를 빠르게 구할 것인가
#
# ※ 유클리드 호제법을 사용해서 풀어야 하는 문제

# %%
# 유클리드 호제법: 최대공약수를 구하는 방법
# 구글링
def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

# %%
gcd(6, 15)
# Out:
# 3

# %%
# 최소공배수도 구해보자
def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

def lcm(a, b):
    return a * b // gcd(a,b)

# %%
lcm(6, 15)
# Out:
# 30

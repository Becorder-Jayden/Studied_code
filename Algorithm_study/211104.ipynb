# %% [markdown]
# # 2021.11.04

# %%
# Silver V
# 2217 로프

N = int(input())
weights = sorted([int(input()) for i in range(N)])
w = []

cnt = 0
for i, j in enumerate(weights):
    result = (len(weights)-i) * j
    w.append(result)
print(max(w))
# Out:
#  4
#  3
#  6
#  9
#  12
# 18

# %%
# test case
2
10 15
-> 10 * 2 = 20
-> 15 * 1 = 15
--> max = 20

4
3 6 9 12
-> 3 * 4 = 12 // rope[0]*N
-> 6 * 3 = 18 // rope[1]*(N-1)
-> 9 * 2 = 18 // rope[2]*(n-2)
-> 12* 1 = 12 // rope[3]*(n-3)
--> max = 18

# %% [markdown]
# # 2021.11.26

# %%
# Silver III
# 11399 ATM

# %%
N = int(input())

people = list(map(int, input().split()))
people = sorted(people)

time = [0]
for i in people:
    time.append(time[-1]+i)

print(sum(time))
# time에 0을 넣지 않고 사용하는 방법?
# Out:
#  5
#  3 1 4 3 2
# [1, 2, 3, 3, 4]
# [0, 1]
# [0, 1, 3]
# [0, 1, 3, 6]
# [0, 1, 3, 6, 9]
# [0, 1, 3, 6, 9, 13]
# 32

# %% [markdown]
# ---

# %%
# 하노이 탑 이동 순서
# Silver II

# %%
N = int(input())
hanoi = [0, 0, 0]

# K값
def K(N):
    if N<2:
        return 1
    else :
        return 2*N+1
print(K(N))

hanoi[0] = N

# 이동 방식
# for i in range(K(N)):
# Out:
#  3
# 7
# [3, 0, 0]

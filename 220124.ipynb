# %% [markdown]
# # 2022.01.24

# %%
# Silver III
# 14889 스타트와 링크

# %%
N = int(input())
li = [i+1 for i in range(N)]
# graph = []

# for i in range(N):
#     arr = list(map(int, input().split()))
#     graph.append(arr)
    

def dfs(start, seq):
    if len(seq)==N//2:
        team_1.append(seq)
        return
    
    for i in range(1, N+1):
        if i not in seq:
            seq.append(i)
            dfs(start, seq)
            seq.pop()
# Out:
#  6
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

# %%
# 두 개의 팀 조합 만들기

N = 6
li = [i+1 for i in range(N)]
# print(li)

def dfs(start, team_1):
    if len(team_1) == N//2:
        print(list(sorted(team_1)))
        return
    
    for i in range(1, N+1):
        if i not in team_1:
            team_1.append(i)
            dfs(start, team_1)
            team_1.pop()
            
print(dfs(1, []))
# Out:
# [1, 2, 3]
# [1, 2, 4]
# [1, 2, 5]
# [1, 2, 6]
# [1, 2, 3]
# [1, 3, 4]
# [1, 3, 5]
# [1, 3, 6]
# [1, 2, 4]
# [1, 3, 4]
# [1, 4, 5]
# [1, 4, 6]
# [1, 2, 5]
# [1, 3, 5]
# [1, 4, 5]
# [1, 5, 6]
# [1, 2, 6]
# [1, 3, 6]
# [1, 4, 6]
# [1, 5, 6]
# [1, 2, 3]
# [1, 2, 4]
# [1, 2, 5]
# [1, 2, 6]
# [1, 2, 3]
# [2, 3, 4]
# [2, 3, 5]
# [2, 3, 6]
# [1, 2, 4]
# [2, 3, 4]
# [2, 4, 5]
# [2, 4, 6]
# [1, 2, 5]
# [2, 3, 5]
# [2, 4, 5]
# [2, 5, 6]
# [1, 2, 6]
# [2, 3, 6]
# [2, 4, 6]
# [2, 5, 6]
# [1, 2, 3]
# [1, 3, 4]
# [1, 3, 5]
# [1, 3, 6]
# [1, 2, 3]
# [2, 3, 4]
# [2, 3, 5]
# [2, 3, 6]
# [1, 3, 4]
# [2, 3, 4]
# [3, 4, 5]
# [3, 4, 6]
# [1, 3, 5]
# [2, 3, 5]
# [3, 4, 5]
# [3, 5, 6]
# [1, 3, 6]
# [2, 3, 6]
# [3, 4, 6]
# [3, 5, 6]
# [1, 2, 4]
# [1, 3, 4]
# [1, 4, 5]
# [1, 4, 6]
# [1, 2, 4]
# [2, 3, 4]
# [2, 4, 5]
# [2, 4, 6]
# [1, 3, 4]
# [2, 3, 4]
# [3, 4, 5]
# [3, 4, 6]
# [1, 4, 5]
# [2, 4, 5]
# [3, 4, 5]
# [4, 5, 6]
# [1, 4, 6]
# [2, 4, 6]
# [3, 4, 6]
# [4, 5, 6]
# [1, 2, 5]
# [1, 3, 5]
# [1, 4, 5]
# ...

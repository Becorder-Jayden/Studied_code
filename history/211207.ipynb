# %% [markdown]
# # 2021.12.07

# %%
# Silver II
# 9184 신나는 함수 실행

# %%
while True:
    a, b, c = map(int, input().split())
    print(a, b, c)
    if (a==-1) & (b==-1) & (c==-1):
        break
# Out:
#  5 6 7
# 5 6 7
#  -1 -1 0
# -1 -1 0
#  -1 -1 -1
# -1 -1 -1

# %%
def w(a, b, c):
    if (a<=0) | (b<=0) | (c<=0):
        return 1
    elif (a>20) | (b>20) | (c>20):
        return w(20, 20, 20)
    elif a < b < c:
        return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
    else:
        return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
        
while True:
    a, b, c = map(int, input().split())
    print(w(a, b, c))
# Out:
#  1 1 1
# 2
#  2 2 2
# 4
#  10 4 6
# 523
#  50 50 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in <module>
#      11 while True:
#      12     a, b, c = map(int, input().split())
# ---> 13     print(w(a, b, c))
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       3         return 1
#       4     elif (a>20) | (b>20) | (c>20):
# ----> 5         return w(20, 20, 20)
#       6     elif a < b < c:
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
# ----> 9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#      10
#      11 while True:
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       5         return w(20, 20, 20)
#       6     elif a < b < c:
# ----> 7         return w(a, b, c-1) + w(a, b-1, c-1) - w(a, b-1, c)
#       8     else:
#       9         return w(a-1, b, c) + w(a-1, b-1, c) + w(a-1, b, c-1) - w(a-1, b-1, c-1)
#
# ~\AppData\Local\Temp/ipykernel_19040/924998427.py in w(a, b, c)
#       1 def w(a, b, c):
# ----> 2     if (a<=0) | (b<=0) | (c<=0):
#       3         return 1
#       4     elif (a>20) | (b>20) | (c>20):
#       5         return w(20, 20, 20)
#
# KeyboardInterrupt:

# %%
# 구글 검색

def w(a, b, c):
    if a <= 0 or b <= 0 or c <= 0:
        return 1
    elif a > 20 or b > 20 or c > 20:
        return w(20, 20, 20)

    if dp[a][b][c] :
        return dp[a][b][c]

    if a<b<c :
        dp[a][b][c] = w(a,b,c-1) + w(a,b-1,c-1) - w(a,b-1,c)
    else:
        dp[a][b][c] = w(a-1,b,c) + w(a-1,b-1,c) + w(a-1,b,c-1) - w(a-1,b-1,c-1)

    return dp[a][b][c]



dp = [[[0 for _ in range(21)] for _ in range (21)] for _ in range (21)]
while True:
    a,b,c = map(int, input().split())
    if a==-1 and b==-1 and c==-1:
        break
    print("w({}, {}, {}) = {}".format(a,b,c,w(a,b,c)))
# Out:
#  10 4 6
# w(10, 4, 6) = 523
#  -1 -1 -1

# %%
# 거스름돈 답안 예시

n = 1260
count = 0

# 큰 단위의 화폐부터 차례대로 확인
array = [500, 100, 50, 10]

for coin in array:
    count += n//coin # 해당 화폐로 거슬러 줄 수 있는 동전의 개수 세기
    n %= coin
    
print(count)
# Out:
# 6
